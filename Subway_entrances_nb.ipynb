# %% [markdown]
# # Pre Processign and Analyzing Subway Entrances

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import geopandas as gpd
# %matplotlib inline

pd.set_option("max_rows",100)

# %%
# Filepath to read Subway entrances shapefile
filepath_subway_entrances = "Subway Entrances Shapefiles/geo_export_485d1373-2cdc-4b7b-a550-584bb82e0d6f.shp"
filepath_nyc_boundaries = "Borough Boundaries/geo_export_df017658-06e6-4fbf-8be1-4070c446823f.shp"

# %%
Subway_gdf = gpd.read_file(filepath_subway_entrances)
NYC_gdf = gpd.read_file(filepath_nyc_boundaries)

# %%
NYC_gdf
# Out:
#    boro_code      boro_name    shape_area     shape_leng  \
# 0        4.0         Queens  3.040206e+09  900269.280485
# 1        3.0       Brooklyn  1.934167e+09  728477.954082
# 2        5.0  Staten Island  1.623631e+09  325924.002076
# 3        1.0      Manhattan  6.366208e+08  359993.126318
# 4        2.0          Bronx  1.187194e+09  463868.599917
#
#                                             geometry
# 0  MULTIPOLYGON (((-73.82645 40.59053, -73.82642 ...
# 1  MULTIPOLYGON (((-73.86327 40.58388, -73.86381 ...
# 2  MULTIPOLYGON (((-74.05051 40.56642, -74.05047 ...
# 3  MULTIPOLYGON (((-74.01093 40.68449, -74.01193 ...
# 4  MULTIPOLYGON (((-73.89681 40.79581, -73.89694 ...

# %%
NYC_gdf.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Dropping NA for now
# ## Better way to preprocess is to either physically fill values or assign name based on Closest station name

# %%
Subway_gdf.dropna(inplace=True)

# %%
Subway_gdf.head()
# Out:
#   line                                     name  objectid  \
# 0  2-5  Birchall Ave & Sagamore St at NW corner    1734.0
# 1  2-5  Birchall Ave & Sagamore St at NE corner    1735.0
# 2  2-5  Morris Park Ave & 180th St at NW corner    1736.0
# 3  2-5  Morris Park Ave & 180th St at NW corner    1737.0
# 4  2-5        Boston Rd & 178th St at SW corner    1738.0
#
#                                  url                    geometry
# 0  http://web.mta.info/nyct/service/  POINT (-73.86836 40.84917)
# 1  http://web.mta.info/nyct/service/  POINT (-73.86821 40.84913)
# 2  http://web.mta.info/nyct/service/  POINT (-73.87350 40.84122)
# 3  http://web.mta.info/nyct/service/  POINT (-73.87289 40.84145)
# 4  http://web.mta.info/nyct/service/  POINT (-73.87962 40.84082)

# %%
Subway_gdf.plot()
# Out:
# <AxesSubplot:>

# %%
#Check if CRS of NYC and Subway system are same
NYC_gdf.crs == Subway_gdf.crs
# Out:
# True

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 12))
NYC_gdf['geometry'].plot(axes=ax, color = 'lightgray')
Subway_gdf.plot(axes=ax , color='orange', markersize=5)
plt.title('Subway Stations in NYC')
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/geopandas/plotting.py:370: FutureWarning: 'axes' is deprecated, please use 'ax' instead (for consistency with pandas)
#   warnings.warn(
# /opt/anaconda3/lib/python3.8/site-packages/geopandas/plotting.py:637: FutureWarning: 'axes' is deprecated, please use 'ax' instead (for consistency with pandas)
#   warnings.warn(
# Text(0.5, 1.0, 'Subway Stations in NYC')
